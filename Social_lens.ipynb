# %% [markdown]
# # While Kaif and Zoya are collecting the real data, we continue building the core of our project using a simple demo dataset.
# # This lets us solidify the parsing logic so that the moment the actual field data arrives, the program will already be ready
# # to handle it.

# %%
# We begin by loading the demo text file. The file contains multiple profiles, each separated by an empty line.
with open("dataset/Social_data.txt",encoding="utf-8")as f:
    data=f.read()

#Printing the variable shows the raw text exactly as it appears in the file.
print(data)
# Out:
# techie_koramangala
# 420 posts
# 9,800 followers
# 310 following
# Arjun M.
# Software Engineer
# 💻 Full-stack @ SaaS startup
# ☕ Working from cafes in Koramangala
# github.com/arjunmakes
#
# blrcoder_girl
# 150 posts
# 6,300 followers
# 120 following
# Riya Codes
# Tech Creator
# 👩‍💻 Python | ML | Roadmaps
# 🎥 Coding Reels + Daily Motivation
# linktr.ee/riyacodes
#
# hsr_startup_stories
# 980 posts
# 22.4K followers
# 95 following
# Startup Stories HSR
# Media
# 🚀 Interviews with Bangalore founders
# 🎙️ Weekly startup breakdowns
# hsrstartupstories.com
#
# cloud_dev_blr
# 210 posts
# 4,500 followers
# 60 following
# Naveen DevOps
# Engineer
# ☁️ AWS | Docker | K8s
# 📍 Sarjapur
# github.com/naveencloud
#
# koramangala_coffee_lover
# 300 posts
# 7,900 followers
# 180 following
# Sana B.
# Cafe Explorer
# ☕ Reviewing Bangalore’s hidden coffee spots
# 📍 Koramangala
# youtube.com/@sanacafehunter
#
# ai_bangalore_news
# 1,340 posts
# 38K followers
# 200 following
# AI Bangalore
# Media
# 🤖 Daily AI news from India
# 📢 Startup & research updates
# aibanglore.ai/news
#
# techfounder_india
# 210 posts
# 19K followers
# 450 following
# Dev Patel
# Founder
# ⚡ Building SaaS in Fintech
# 📍 Indiranagar
# devpatel.io
#
# coder_on_orr
# 65 posts
# 1,900 followers
# 70 following
# Sriram
# Backend Developer
# 🐍 Python | FastAPI enthusiast
# 🌧️ Surviving ORR traffic
# github.com/sriramworks
#
# blrdatascience_daily
# 540 posts
# 15.1K followers
# 150 following
# Bangalore DS Daily
# Media
# 📊 Data + AI + ML
# 👩‍🏫 Tutorials | Job alerts
# blrdatascience.in
#
# frontend_with_megha
# 175 posts
# 8,200 followers
# 95 following
# Megha Gupta
# Frontend Dev
# 🎨 React | Next.js | UI Tips
# 🌸 Bengaluru
# meghacodes.dev
#
# cubbonpark_runner
# 95 posts
# 1,500 followers
# 40 following
# Aman
# Lifestyle
# 🏃 Running after coding
# 📍 Cubbon Park
# strava.com/amanrunning
#
# indiranagar_food_maps
# 600 posts
# 12.3K followers
# 155 following
# Food Maps BLR
# Food & Drink
# 🍜 Maps of best places around Indiranagar
# 📍 Bangalore
# foodmapsblr.com
#
# python_blr_jobs
# 1,200 posts
# 21K followers
# 18 following
# Python Jobs BLR
# Community
# 💼 Python/ML/AI jobs daily
# 📍 Bengaluru
# pythonblr.jobs
#
# sarjapur_coder
# 143 posts
# 3,200 followers
# 52 following
# Roshan
# Full-stack Dev
# 🧑‍💻 MERN | DevTools
# Currently debugging from Sarjapur
# roshancodes.dev
#
# open_source_blr
# 300 posts
# 9,100 followers
# 78 following
# BLR Open Source
# Community
# 🌐 Meetups | Talks | OSS
# github.com/blropensource
#
# techwalk_blr
# 430 posts
# 11K followers
# 320 following
# Tech Walk Bangalore
# Media
# 🚶 Exploring tech parks & cafes
# 📍 Ecoworld | Manyata | Bagmane
# techwalkblr.com
#
# itpl_daily
# 590 posts
# 14.2K followers
# 210 following
# ITPL Daily
# Blog
# 🏢 Inside Whitefield Tech Life
# 🚌 Bus stand stories included
# medium.com/@itpldaily
#
# react_native_blr
# 220 posts
# 4,700 followers
# 60 following
# RN Bangalore
# Community
# 📱 React Native Tips | Meetups
# rnblr.dev
#
# founder_doodles
# 80 posts
# 2,300 followers
# 20 following
# Kushal
# Artist + Coder
# ✏️ Startup doodles
# 💻 YC fanboy
# kushaldraws.com
#
# blrproductmanager
# 160 posts
# 6,800 followers
# 110 following
# Sanya | PM
# Product Manager
# 📍 Koramangala
# 🔍 Breaking down apps
# sanyapm.com
#
# machinelearning_blr
# 490 posts
# 17.8K followers
# 140 following
# ML Bangalore
# Community
# 🤖 Workshops | Resources
# mlblr.in
#
# bengaluru_startup_recruiter
# 135 posts
# 5,900 followers
# 300 following
# Ankita HR
# Recruiter
# 🦄 Hiring for early-stage startups
# 📍 Indiranagar
# ankitarecruits.in
#
# coffeeandcode_blr
# 77 posts
# 1,400 followers
# 44 following
# Aditya
# Developer
# ☕ Coffee + VSCode = Happiness
# 📍 HSR
# github.com/coffeeandcodeblr
#
# uiux_blr_design
# 210 posts
# 9,500 followers
# 130 following
# UI/UX Bangalore
# Design
# 🎨 Case studies, tips, mock UI
# uiuxblr.design
#
# whitefield_cafe_explorer
# 480 posts
# 7,600 followers
# 250 following
# Radhika
# Cafe Nerd
# ☕ Whitefield cafes & reading corners
# 📘 Book recs
# instareadsblr.com
#
# jslover_bangalore
# 120 posts
# 3,800 followers
# 32 following
# Jatin Codes
# Engineer
# ⚡ JavaScript everything
# 📍 MG Road
# github.com/jatincodesjs
#
# blrautotechtalk
# 310 posts
# 8,400 followers
# 260 following
# AutoTech BLR
# Media
# 🚗 EVs | Autonomous | Mobility
# 📍 Bengaluru
# autotechblr.com
#
# deeptech_india
# 900 posts
# 24K followers
# 290 following
# DeepTech India
# Media
# 🛠️ Indian AI + Robotics + Chips
# deeptechindia.ai
#
# startupdating_blr
# 140 posts
# 5,000 followers
# 40 following
# Startup Dating
# Blog
# 💔 Founders + Investors = Drama
# 📍 HSR
# medium.com/startupdatingblr
#
# codingkannadiga
# 190 posts
# 7,200 followers
# 150 following
# Praveen
# Tech Creator
# 💻 Python + Kannada Tutorials
# youtube.com/@codingkannadiga
#
# koramangala_hustlers
# 800 posts
# 18.7K followers
# 300 following
# Koramangala Hustlers
# Lifestyle
# 💼 Startups, events, coworks
# korahustlers.com
#
# mlops_blr
# 210 posts
# 6,400 followers
# 70 following
# MLOps Bangalore
# Community
# 🛠️ ML infra | Deployments
# mlopsblr.in
#
# producthunt_blr
# 340 posts
# 10.5K followers
# 190 following
# Product Hunt BLR
# Media
# 🚀 New launches from Indian builders
# producthuntblr.com
#
# ai_research_india
# 170 posts
# 8,800 followers
# 60 following
# AI Research India
# Education
# 📄 Papers, datasets, repos
# airesearchindia.org
#
# fullstack_dev_anjali
# 90 posts
# 2,100 followers
# 35 following
# Anjali
# Developer
# 🌈 Full-stack tutorials
# 📍 BTM Layout
# anjalicodes.tech
#
# bangalorebikecoder
# 60 posts
# 1,300 followers
# 30 following
# Vijay
# Coder
# 🚴 Cycling to office, coding after
# 📍 Bellandur
# strava.com/vijayblr
#
# codewithchai_blr
# 110 posts
# 3,400 followers
# 50 following
# Chai + Code
# Lifestyle
# ☕ Chai spots + dev stories
# chaiandcode.com
#
# indiranagar_startuplab
# 220 posts
# 12K followers
# 160 following
# Startup Lab
# Community
# 🧪 Experiments with early-stage founders
# indiranagarstartuplab.com
#
# pythonforkids_blr
# 95 posts
# 2,700 followers
# 22 following
# Python Kids BLR
# Education
# 👶 Coding classes for kids
# pythonforkidsblr.in
#
# devrel_blr
# 180 posts
# 7,900 followers
# 70 following
# DevRel Bangalore
# Community
# 🎤 Talks | Dev advocacy | Tools
# devrelblr.org
#
# techpark_memes
# 350 posts
# 16K followers
# 250 following
# Tech Park Memes
# Comedy
# 😂 Jokes from Ecospace, Manyata & more
# bit.ly/techparkmemes
#
# hsr_designstudio
# 400 posts
# 9,400 followers
# 280 following
# HSR Design Studio
# Design
# 🖌️ Freelance UI/UX
# 📍 HSR
# hsrdesignstudio.in
#
# kaggler_blr
# 130 posts
# 4,200 followers
# 40 following
# Kaggle Bangalore
# Data Science
# 📊 Competitions, kernels
# kagglerblr.com
#
# datascience_rider
# 75 posts
# 1,600 followers
# 33 following
# Naman
# Data Scientist
# 🏍️ Rides + ML
# 📍 Indiranagar
# namanml.dev
#
# bootcamp_blr
# 310 posts
# 8,600 followers
# 80 following
# Bangalore Bootcamp
# Education
# 👩‍💻 Coding bootcamps & workshops
# bootcampblr.in
#
# buildinpublic_blr
# 270 posts
# 6,200 followers
# 50 following
# Build in Public BLR
# Community
# 📈 Indie hackers & SaaS founders
# buildinpublicblr.com
#
# intaglobal
# 1,946 posts
# 6,851 followers
# 262 following
# INTA
# Nonprofit organization
# The association of ™ professionals.
# inta.campsite.bio
#
# _anujsinghal
# 1,785 posts
# 681K followers
# 248 following
# Anuj Singhal
# Digital creator
# Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India
# Let’s talk about finance and life
# Contact: Singhalanuj1010@gmail.com
# hindi.cnbctv18.com/market-gurukul
#
# code_flare
# 165 posts
# 216 followers
# 10 following
# The Journey Notebook | Travel | Food Blogger
# Blogger
# 📍 Exploring places & phases of life 🌍
# .
# 🍵 From chai breaks to flight takes ✈️
# .
# 💫 Travel | Food | Daily life 🌸
# youtube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a
#
# bangalore_tech_bro
# 402 posts
# 12.5K followers
# 890 following
# Rahul | HSR Hustler
# Entrepreneur
# 🚀 Building the next Unicorn in Fintech
# ☕ 3rd Wave Coffee addict
# 💻 Python | React | AI
# 📍 HSR Layout, BLR
# linktr.ee/rahulbuilds
#
# silkboard_survivor
# 55 posts
# 1,200 followers
# 50 following
# Priya D.
# Public Figure
# 🚦 Stuck in traffic since 2019
# 🌧️ Loving the Bangalore weather, hating the cabs
# 🐍 Data Scientist by day, meme maker by night
# 📍 ORR
# bit.ly/my-traffic-rants
#
# startuphub_blr
# 2,300 posts
# 45K followers
# 120 following
# Startup Hub Bangalore
# Media
# 🦄 News from the Silicon Valley of India
# 📢 Funding alerts, Hiring trends, and Drama
# 📩 DM for features
# startuphub.blr/newsletter
#
# foodie_in_kora
# 890 posts
# 5,600 followers
# 400 following
# Sneha | Bangalore Eats
# Food & Drink
# Aagrah to Truffles 🍔
# Exploring Koramangala's cafe culture ☕
# DM for collabs
# https://www.google.com/search?q=zomato.com/users/sneha123
#
# venture_vikram
# 120 posts
# 30K followers
# 500 following
# Vikram | Angel Investor
# Investor
# 💸 Helping founders go 0 to 1
# Ex-Google, Ex-Amazon
# Investing in DeepTech & AI
# 📍 Indiranagar
# vikram.vc/pitch-deck
#
# python_meetup_blr
# 60 posts
# 3,400 followers
# 10 following
# PyBangalore Community
# Community
# 🐍 Weekly meetups for Pythonistas
# 📍 Cubbon Park | Sundays 4 PM
# Coding + Coffee + Community
# https://www.google.com/search?q=meetup.com/pybangalore
#
# indiranagar_gossip
# 300 posts
# 8,900 followers
# 20 following
# Indiranagar Spy
# Personal Blog
# Not just about 100ft Road 🤫
# Spilling tea on the best brunches and worst landlords
# Bengaluru
# https://www.google.com/search?q=medium.com/%40indiranagarspy
#
#
# techtrail_blr
# 340 posts
# 9,100 followers
# 210 following
# Tech Trail Bangalore
# Media
# 🚀 Startup scoops & tech tales
# 💡 Covering Koramangala, HSR & Indiranagar
# 📍 BLR
# linktr.ee/techtrailblr
#
# koramangala_coder
# 120 posts
# 2,800 followers
# 95 following
# Kora Coder
# Personal Blog
# 💻 Daily coding challenges
# ☕ Cafe-hopping + LeetCode
# 📍 Koramangala
# [https://www.google.com/search?q=koramangala+coder](https://www.google.com/search?q=koramangala+coder)
#
# blrcowork_chronicles
# 480 posts
# 6,700 followers
# 180 following
# Cowork Chronicles BLR
# Community
# 🏢 Exploring coworking spaces
# 👨‍💻 For freelancers & founders
# 📍 Bellandur
# bit.ly/cowork-chronicles
#
# devhub_koramangala
# 210 posts
# 4,500 followers
# 60 following
# DevHub Koramangala
# Community
# 👨‍💻 Nightly coding jams
# 📚 React | Python | AI
# 📍 Koramangala 5th Block
# [https://www.google.com/search?q=devhub+koramangala](https://www.google.com/search?q=devhub+koramangala)
#
# ai_bengaluru
# 150 posts
# 15.2K followers
# 140 following
# AI Bengaluru
# Tech
# 🤖 AI trends, events & demos
# 📍 BLR
# ai-blr.tech
#
# frontend_blr
# 95 posts
# 3,900 followers
# 30 following
# Frontend BLR
# Community
# 🎨 UI/UX | Web Dev | Tailwind
# 📍 Indiranagar
# [https://www.google.com/search?q=frontendblr](https://www.google.com/search?q=frontendblr)
#
# hsr_startup_stories
# 600 posts
# 22K followers
# 300 following
# HSR Startup Stories
# Media
# 🦄 Founder journeys from HSR
# 📍 BLR
# hsrstartups.in
#
# python_wallah_blr
# 80 posts
# 1,700 followers
# 40 following
# Python Wallah BLR
# Educator
# 🐍 Python tips daily
# 📍 BTM Layout
# pythonwallah.in
#
# btm_dev_cafe
# 140 posts
# 2,200 followers
# 120 following
# Dev Café BTM
# Community
# ☕ Coffee + Code sessions
# 📍 BTM Layout
# linktr.ee/btmdevcafe
#
# blrautomation_club
# 90 posts
# 5,800 followers
# 65 following
# Automation Club BLR
# Community
# 🛠️ RPA | Python Scripts | AI
# 📍 KR Puram
# [https://www.google.com/search?q=blrautomationclub](https://www.google.com/search?q=blrautomationclub)
#
# coding_koramangala
# 70 posts
# 1,350 followers
# 15 following
# Coding Koramangala
# Community
# 👨‍💻 Weekly coding walks
# 📍 Koramangala
# bit.ly/coding-kormangala
#
# devlife_bangalore
# 430 posts
# 18K followers
# 450 following
# DevLife Bangalore
# Blog
# 💼 Life of BLR developers
# ☕ Cafes, layoffs & chai
# devlifeblr.medium.com
#
# cloud_blr
# 160 posts
# 9,400 followers
# 210 following
# Cloud BLR
# Tech
# ☁️ Cloud + DevOps content
# 📍 Electronic City
# cloudblr.dev
#
# electroniccity_coder
# 100 posts
# 3,100 followers
# 55 following
# ECity Coder
# Personal Blog
# 💻 Python backend dev
# 📍 E-city Phase 1
# [https://www.google.com/search?q=ecity+coder](https://www.google.com/search?q=ecity+coder)
#
# bangalore_datascience_club
# 240 posts
# 12.7K followers
# 110 following
# BLR Data Science Club
# Community
# 📊 ML sessions + Kaggle nights
# 📍 MG Road WeWork
# datascienceblr.club
#
# blrmobiledevs
# 130 posts
# 4,200 followers
# 80 following
# BLR Mobile Devs
# Community
# 📱 Flutter | React Native
# 📍 Indiranagar
# [https://www.google.com/search?q=blrmobiledevs](https://www.google.com/search?q=blrmobiledevs)
#
# react_bangalore
# 300 posts
# 14K followers
# 200 following
# React Bangalore
# Community
# ⚛️ React meetups & workshops
# 📍 BLR
# reactblr.dev
#
# devs_of_whitefield
# 190 posts
# 6,600 followers
# 150 following
# Whitefield Devs
# Community
# 💻 Tech + productivity
# 📍 Whitefield
# whitefielddevs.in
#
# indiranagar_debugger
# 75 posts
# 2,000 followers
# 30 following
# Indiranagar Debugger
# Blog
# 🐞 Debugging life & code
# 📍 Indiranagar
# bit.ly/indiranagar-debugger
#
# koramangala_ai_meet
# 85 posts
# 7,400 followers
# 22 following
# Kora AI Meet
# Community
# 🤖 AI jam sessions
# 📍 Koramangala 1st Block
# kora-ai.club
#
# blrit_guy
# 230 posts
# 5,300 followers
# 200 following
# BLR IT Guy
# Public Figure
# 💼 Big Tech employee life
# 📍 Manyata Tech Park
# [https://www.google.com/search?q=blr+it+guy](https://www.google.com/search?q=blr+it+guy)
#
# startup_grind_bangalore
# 1,100 posts
# 38K followers
# 420 following
# Startup Grind Bangalore
# Community
# 🔥 Founder wisdom + events
# 📍 BLR
# startupgrind.com/bangalore
#
# coding_in_indiranagar
# 60 posts
# 1,100 followers
# 25 following
# Coding in Indiranagar
# Personal Blog
# 👨‍💻 Python & JS notes
# 📍 100ft Road
# bit.ly/coding-indiranagar
#
# devwalk_blr
# 50 posts
# 900 followers
# 15 following
# Dev Walk BLR
# Community
# 🚶‍♂️ Walk + talk tech
# 📍 Lalbagh
# devwalk.in
#
# bellandur_bug_hunter
# 110 posts
# 3,900 followers
# 75 following
# Bellandur Bug Hunter
# Blog
# 🐛 QA life in BLR
# 📍 Bellandur
# tinyurl.com/bughunterblr
#
# blrcoders_space
# 340 posts
# 25K followers
# 300 following
# BLR Coders Space
# Community
# 👨‍💻 Coding news, memes
# 📍 BLR
# blrcoders.space
#
# nextjs_blr
# 45 posts
# 2,300 followers
# 40 following
# Next.js Bangalore
# Community
# ⚡ Modern web dev meetups
# 📍 MG Road
# nextjsblr.dev
#
# techpark_musings
# 130 posts
# 6,000 followers
# 100 following
# Tech Park Musings
# Blog
# 🏢 Manyata | EcoSpace | Bagmane
# 📍 Bangalore
# medium.com/@techparkmusings
#
# koramangala_freelancers
# 200 posts
# 4,000 followers
# 70 following
# Koramangala Freelancers
# Community
# 💻 Remote work + gigs
# 📍 Koramangala
# korafreelancers.co
#
# blronlinejobs
# 560 posts
# 21K followers
# 190 following
# BLR Online Jobs
# Media
# 💼 Hiring in tech daily
# 📍 BLR
# blronlinejobs.in
#
# datascience_daily_blr
# 150 posts
# 8,800 followers
# 140 following
# DS Daily BLR
# Education
# 📊 ML tricks & resources
# 📍 BLR
# dsdailyblr.com
#
# python_koramangala
# 42 posts
# 850 followers
# 12 following
# Python Koramangala
# Community
# 🐍 Weekly Python tasks
# 📍 Koramangala
# bit.ly/python-kora
#
# coding_chai_bangalore
# 280 posts
# 10K followers
# 230 following
# Coding Chai
# Blog
# ☕ Code + chai
# 📍 JP Nagar
# codingchai.in
#
# blrgitcommunity
# 75 posts
# 3,200 followers
# 20 following
# Git Community BLR
# Tech
# 🔧 Git tips & collab sessions
# 📍 BLR
# gitblr.dev
#
# indiranagar_startups
# 320 posts
# 12.5K followers
# 100 following
# Indiranagar Startups
# Media
# 🦄 Spotlight on early-stage founders
# 📍 Indiranagar
# indiranagarstartups.in
#
# machinelearning_blr
# 210 posts
# 19K followers
# 250 following
# Machine Learning BLR
# Tech
# 🤖 ML articles & demos
# 📍 BLR
# mlblr.tech
#
# koramangala_script_kiddie
# 55 posts
# 1,050 followers
# 18 following
# Script Kiddie Kora
# Personal Blog
# 💻 Learning Python & JS
# 📍 Koramangala
# [https://www.google.com/search?q=script+kiddie+kora](https://www.google.com/search?q=script+kiddie+kora)
#
# hsr_dev_buddy
# 120 posts
# 2,700 followers
# 40 following
# HSR Dev Buddy
# Community
# 👨‍💻 Peer learning club
# 📍 HSR Layout
# hsrdevbuddy.in
#
# blrcloudhackers
# 140 posts
# 7,900 followers
# 200 following
# BLR Cloud Hackers
# Tech
# ☁️ AWS | Azure | GCP
# 📍 BLR
# cloudhackers.in
#
# techwriter_blr
# 60 posts
# 1,900 followers
# 50 following
# BLR Tech Writer
# Writer
# 📝 Tech explainers
# 📍 Bangalore
# medium.com/@blrtechwriter
#
# dev_canteen_koramangala
# 180 posts
# 5,400 followers
# 120 following
# Dev Canteen
# Community
# 🍔 Food + code meetups
# 📍 Koramangala
# devcanteen.in
#
# pythonlady_blr
# 70 posts
# 4,200 followers
# 35 following
# Python Lady BLR
# Educator
# 🐍 Python + data tutorials
# 📍 Indiranagar
# pythonlady.in
#
# bangalore_oss
# 250 posts
# 9,800 followers
# 90 following
# Bangalore Open Source
# Community
# 🛠️ OSS projects & contributions
# 📍 BLR
# ossblr.dev
#
# blr_ai_founders
# 85 posts
# 6,600 followers
# 70 following
# BLR AI Founders
# Entrepreneur
# 🤖 AI startup builders
# 📍 Indiranagar
# aifoundersblr.com
#
# coders_of_bangalore
# 300 posts
# 17K followers
# 280 following
# Coders of Bangalore
# Community
# 👨‍💻 Showcasing BLR devs
# 📍 BLR
# codersofbangalore.in
#
# dailydev_bangalore
# 180 posts
# 12.2K followers
# 200 following
# Daily Dev Bangalore
# Tech
# 📝 Tips | Tools | Tutorials
# 📍 BLR
# dailydevblr.co
#
# bangalore_backend
# 90 posts
# 4,800 followers
# 60 following
# BLR Backend Devs
# Tech
# 🔧 Python | Go | Node
# 📍 BLR
# backendblr.tech
#
# ecity_techies
# 140 posts
# 3,900 followers
# 55 following
# E-city Techies
# Community
# 💼 Tech park life
# 📍 Electronic City
# ecitytechies.in
#
# fullstack_blr_club
# 110 posts
# 7,200 followers
# 85 following
# Fullstack BLR Club
# Community
# 💻 MERN | Python | DevOps
# 📍 JP Nagar
# fullstackblr.club
#
# coding_runners_blr
# 100 posts
# 2,500 followers
# 35 following
# Coding Runners
# Community
# 🏃‍♂️ Running + coding
# 📍 Cubbon Park
# codingrunners.in
#
# bangalore_engineers_diary
# 270 posts
# 8,500 followers
# 120 following
# Engineers Diary BLR
# Blog
# 📘 Life & tech rants
# 📍 BLR
# medium.com/@engineersdiaryblr

# %%
# The next step is to break the data into individual profile blocks. Each profile in the file is separated 
# by two newline characters, so splitting on that pattern gives us separate units to work with.

chunks=data.split("\n\n")
chunks=[ch for ch in chunks if len (ch)>3]
# print(chunks)

# %%
# The list contains one chunk per profile. To examine a single profile and better understand the format.
chunks[1]
# Out:
# 'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'

# %%
# The goal is to convert each chunk from raw text into a clean Python dictionary. For that, we define a function 
# that trims extra whitespace, separates the lines, removes labels, and returns the meaningful parts.

def parse_chunk(chunk):
    chunk=chunk.strip()
    lines=chunk.split("\n")
    name=lines[0].replace("Name: ","")
    posts=lines[1].replace("Posts: ","")
    follwers=lines[2].replace("Followers: ", "")
    bio=lines[3].replace("Bio: ","")

    return {"name":name, "posts":posts, "followers":follwers, "bio":bio}

# check the chunks step by step
print(parse_chunk(chunks[5]))   

# Running the function on a sample chunk gives a structured dictionary containing the name, 
# posts, followers and bio fields extracted from the original text
# Out:
# {'name': 'ai_bangalore_news', 'posts': '1,340 posts', 'followers': '38K followers', 'bio': '200 following'}

# %%
all_chunks=[]
for chunk in chunks:
    parsed_chunk =parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'name': 'techie_koramangala', 'posts': '420 posts', 'followers': '9,800 followers', 'bio': '310 following'}, {'name': 'blrcoder_girl', 'posts': '150 posts', 'followers': '6,300 followers', 'bio': '120 following'}, {'name': 'hsr_startup_stories', 'posts': '980 posts', 'followers': '22.4K followers', 'bio': '95 following'}, {'name': 'cloud_dev_blr', 'posts': '210 posts', 'followers': '4,500 followers', 'bio': '60 following'}, {'name': 'koramangala_coffee_lover', 'posts': '300 posts', 'followers': '7,900 followers', 'bio': '180 following'}, {'name': 'ai_bangalore_news', 'posts': '1,340 posts', 'followers': '38K followers', 'bio': '200 following'}, {'name': 'techfounder_india', 'posts': '210 posts', 'followers': '19K followers', 'bio': '450 following'}, {'name': 'coder_on_orr', 'posts': '65 posts', 'followers': '1,900 followers', 'bio': '70 following'}, {'name': 'blrdatascience_daily', 'posts': '540 posts', 'followers': '15.1K followers', 'bio': '150 following'}, {'name': 'frontend_with_megha', 'posts': '175 posts', 'followers': '8,200 followers', 'bio': '95 following'}, {'name': 'cubbonpark_runner', 'posts': '95 posts', 'followers': '1,500 followers', 'bio': '40 following'}, {'name': 'indiranagar_food_maps', 'posts': '600 posts', 'followers': '12.3K followers', 'bio': '155 following'}, {'name': 'python_blr_jobs', 'posts': '1,200 posts', 'followers': '21K followers', 'bio': '18 following'}, {'name': 'sarjapur_coder', 'posts': '143 posts', 'followers': '3,200 followers', 'bio': '52 following'}, {'name': 'open_source_blr', 'posts': '300 posts', 'followers': '9,100 followers', 'bio': '78 following'}, {'name': 'techwalk_blr', 'posts': '430 posts', 'followers': '11K followers', 'bio': '320 following'}, {'name': 'itpl_daily', 'posts': '590 posts', 'followers': '14.2K followers', 'bio': '210 following'}, {'name': 'react_native_blr', 'posts': '220 posts', 'followers': '4,700 followers', 'bio': '60 following'}, {'name': 'founder_doodles', 'posts': '80 posts', 'followers': '2,300 followers', 'bio': '20 following'}, {'name': 'blrproductmanager', 'posts': '160 posts', 'followers': '6,800 followers', 'bio': '110 following'}, {'name': 'machinelearning_blr', 'posts': '490 posts', 'followers': '17.8K followers', 'bio': '140 following'}, {'name': 'bengaluru_startup_recruiter', 'posts': '135 posts', 'followers': '5,900 followers', 'bio': '300 following'}, {'name': 'coffeeandcode_blr', 'posts': '77 posts', 'followers': '1,400 followers', 'bio': '44 following'}, {'name': 'uiux_blr_design', 'posts': '210 posts', 'followers': '9,500 followers', 'bio': '130 following'}, {'name': 'whitefield_cafe_explorer', 'posts': '480 posts', 'followers': '7,600 followers', 'bio': '250 following'}, {'name': 'jslover_bangalore', 'posts': '120 posts', 'followers': '3,800 followers', 'bio': '32 following'}, {'name': 'blrautotechtalk', 'posts': '310 posts', 'followers': '8,400 followers', 'bio': '260 following'}, {'name': 'deeptech_india', 'posts': '900 posts', 'followers': '24K followers', 'bio': '290 following'}, {'name': 'startupdating_blr', 'posts': '140 posts', 'followers': '5,000 followers', 'bio': '40 following'}, {'name': 'codingkannadiga', 'posts': '190 posts', 'followers': '7,200 followers', 'bio': '150 following'}, {'name': 'koramangala_hustlers', 'posts': '800 posts', 'followers': '18.7K followers', 'bio': '300 following'}, {'name': 'mlops_blr', 'posts': '210 posts', 'followers': '6,400 followers', 'bio': '70 following'}, {'name': 'producthunt_blr', 'posts': '340 posts', 'followers': '10.5K followers', 'bio': '190 following'}, {'name': 'ai_research_india', 'posts': '170 posts', 'followers': '8,800 followers', 'bio': '60 following'}, {'name': 'fullstack_dev_anjali', 'posts': '90 posts', 'followers': '2,100 followers', 'bio': '35 following'}, {'name': 'bangalorebikecoder', 'posts': '60 posts', 'followers': '1,300 followers', 'bio': '30 following'}, {'name': 'codewithchai_blr', 'posts': '110 posts', 'followers': '3,400 followers', 'bio': '50 following'}, {'name ...

# %%
# text file convert to the json file 

import json
s=json.dumps(all_chunks,indent=4)
print(s)
# Out:
# [
#     {
#         "name": "techie_koramangala",
#         "posts": "420 posts",
#         "followers": "9,800 followers",
#         "bio": "310 following"
#     },
#     {
#         "name": "blrcoder_girl",
#         "posts": "150 posts",
#         "followers": "6,300 followers",
#         "bio": "120 following"
#     },
#     {
#         "name": "hsr_startup_stories",
#         "posts": "980 posts",
#         "followers": "22.4K followers",
#         "bio": "95 following"
#     },
#     {
#         "name": "cloud_dev_blr",
#         "posts": "210 posts",
#         "followers": "4,500 followers",
#         "bio": "60 following"
#     },
#     {
#         "name": "koramangala_coffee_lover",
#         "posts": "300 posts",
#         "followers": "7,900 followers",
#         "bio": "180 following"
#     },
#     {
#         "name": "ai_bangalore_news",
#         "posts": "1,340 posts",
#         "followers": "38K followers",
#         "bio": "200 following"
#     },
#     {
#         "name": "techfounder_india",
#         "posts": "210 posts",
#         "followers": "19K followers",
#         "bio": "450 following"
#     },
#     {
#         "name": "coder_on_orr",
#         "posts": "65 posts",
#         "followers": "1,900 followers",
#         "bio": "70 following"
#     },
#     {
#         "name": "blrdatascience_daily",
#         "posts": "540 posts",
#         "followers": "15.1K followers",
#         "bio": "150 following"
#     },
#     {
#         "name": "frontend_with_megha",
#         "posts": "175 posts",
#         "followers": "8,200 followers",
#         "bio": "95 following"
#     },
#     {
#         "name": "cubbonpark_runner",
#         "posts": "95 posts",
#         "followers": "1,500 followers",
#         "bio": "40 following"
#     },
#     {
#         "name": "indiranagar_food_maps",
#         "posts": "600 posts",
#         "followers": "12.3K followers",
#         "bio": "155 following"
#     },
#     {
#         "name": "python_blr_jobs",
#         "posts": "1,200 posts",
#         "followers": "21K followers",
#         "bio": "18 following"
#     },
#     {
#         "name": "sarjapur_coder",
#         "posts": "143 posts",
#         "followers": "3,200 followers",
#         "bio": "52 following"
#     },
#     {
#         "name": "open_source_blr",
#         "posts": "300 posts",
#         "followers": "9,100 followers",
#         "bio": "78 following"
#     },
#     {
#         "name": "techwalk_blr",
#         "posts": "430 posts",
#         "followers": "11K followers",
#         "bio": "320 following"
#     },
#     {
#         "name": "itpl_daily",
#         "posts": "590 posts",
#         "followers": "14.2K followers",
#         "bio": "210 following"
#     },
#     {
#         "name": "react_native_blr",
#         "posts": "220 posts",
#         "followers": "4,700 followers",
#         "bio": "60 following"
#     },
#     {
#         "name": "founder_doodles",
#         "posts": "80 posts",
#         "followers": "2,300 followers",
#         "bio": "20 following"
#     },
#     {
#         "name": "blrproductmanager",
#         "posts": "160 posts",
#         "followers": "6,800 followers",
#         "bio": "110 following"
#     },
#     {
#         "name": "machinelearning_blr",
#         "posts": "490 posts",
#         "followers": "17.8K followers",
#         "bio": "140 following"
#     },
#     {
#         "name": "bengaluru_startup_recruiter",
#         "posts": "135 posts",
#         "followers": "5,900 followers",
#         "bio": "300 following"
#     },
#     {
#         "name": "coffeeandcode_blr",
#         "posts": "77 posts",
#         "followers": "1,400 followers",
#         "bio": "44 following"
#     },
#     {
#         "name": "uiux_blr_design",
#         "posts": "210 posts",
#         "followers": "9,500 followers",
#         "bio": "130 following"
#     },
#     {
#         "name": "whitefield_cafe_explorer",
#         "posts": "480 posts",
#         "followers": "7,600 followers",
#         "bio": "250 following"
#     },
#     {
#         "name": "jslover_bangalore",
#         "posts": "120 posts",
#         "followers": "3,800 followers",
#         "bio": "32 following"
#     },
#     {
#         "name": "blrautotechtalk",
#         "posts": "310 posts",
#         "followers": "8,400 followers",
#         "bio": "260 following"
#     },
#     {
#         "name": "deeptech_india",
#         "posts": "900 posts",
#         "followers": "24K followers",
#         "bio": "290 following"
#     },
#     {
#         "name": "startupdating_blr",
#         "posts": "140 posts",
#         "followers": "5,000 followers",
#         "bio": "40 following"
#     },
#     {
#         "name": "codingkannadiga",
#         "posts": "190 posts",
#         "followers": "7,200 followers",
#         "bio": "150 following"
#     },
#     {
#         "name": "koramangala_hustlers",
#         "posts": "800 posts",
#         "followers": "18.7K followers",
#         "bio": "300 following"
#     },
#     {
#         "name": "mlops_blr",
#         "posts": "210 posts",
#         "followers": "6,400 followers",
#         "bio": "70 following"
#     },
#     {
#         "name": "producthunt_blr",
#         "posts": "340 posts",
#         "followers": "10.5K followers",
#         "bio": "190 following"
#     },
#     {
#         "name": "ai_research_india",
#         "posts": "170 posts",
#         "followers": "8,800 followers",
#         "bio": "60 following"
#     },
#     {
#         "name": "fullstack_dev_anjali",
#         "posts": "90 posts",
#         "followers": "2,100 followers",
#         "bio": "35 following"
#     },
#     {
#         "name": "bangalorebikecoder",
#         "posts": "60 posts",
#         "followers": "1,300 followers",
#         "bio": "30 following"
#     },
#     {
#         "name": "codewithchai_blr",
#         "posts": "110 posts",
#         "followers": "3,400 followers",
#         "bio": "50 following"
#     },
#     {
#         "name": "indiranagar_startuplab",
#         "posts": "220 posts",
#         "followers": "12K followers",
#         "bio": "160 following"
#     },
#     {
#         "name": "pythonforkids_blr",
#         "posts": "95 posts",
#         "followers": "2,700 followers",
#         "bio": "22 following"
#     },
#     {
#         "name": "devrel_blr",
#         "posts": "180 posts",
#         "followers": "7,900 followers",
#         "bio": "70 following"
#     },
#     {
#         "name": "techpark_memes",
#         "posts": "350 posts",
#         "followers": "16K followers",
#         "bio": "250 following"
#     },
#     {
#         "name": "hsr_designstudio",
#         "posts": "400 posts",
#         "followers": "9,400 followers",
#         "bio": "280 following"
#     },
#     {
#         "name": "kaggler_blr",
#         "posts": "130 posts",
#         "followers": "4,200 followers",
#         "bio": "40 following"
#     },
#     {
#         "name": "datascience_rider",
#         "posts": "75 posts",
#         "followers": "1,600 followers",
#         "bio": "33 following"
#     },
#     {
#         "name": "bootcamp_blr",
#         "posts": "310 posts",
#         "followers": "8,600 followers",
#         "bio": "80 following"
#     },
#     {
#         "name": "buildinpublic_blr",
#         "posts": "270 posts",
#         "followers": "6,200 followers",
#         "bio": "50 following"
#     },
#     {
#         "name": "intaglobal",
#         "posts": "1,946 posts",
#         "followers": "6,851 followers",
#         "bio": "262 following"
#     },
#     {
#         "name": "_anujsinghal",
#         "posts": "1,785 posts",
#         "followers": "681K followers",
#         "bio": "248 following"
#     },
#     {
#         "name": "code_flare",
#         "posts": "165 posts",
#         "followers": "216 followers",
#         "bio": "10 following"
#     },
#     {
#         "name": "bangalore_tech_bro",
#         "posts": "402 posts",
#         "followers": "12.5K followers",
#         "bio": "890 following"
#     },
#     {
#         "name": "silkboard_survivor",
#         "posts": "55 posts",
#         "followers": "1,200 followers",
#         "bio": "50 following"
#     },
#     {
#         "name": "startuphub_blr",
#         "posts": "2,300 posts",
#         "followers": "45K followers",
#         "bio": "120 following"
#     },
#     {
#         "name": "foodie_in_kora",
#         "posts": "890 posts",
#         "followers": "5,600 followers",
#         "bio": "400 following"
#     },
#     {
#         "name": "venture_vikram",
#         "posts": "120 posts",
#         "followers": "30K followers",
#         "bio": "500 following"
#     },
#     {
#         "name": "python_meetup_blr",
#         "posts": "60 posts",
#         "followers": "3,400 followers",
#         "bio": "10 following"
#     },
#     {
#         "name": "indiranagar_gossip",
#         "posts": "300 posts",
#         "followers": "8,900 followers",
#         "bio": "20 following"
#     },
#     {
#         "name": "techtrail_blr",
#         "posts": "340 posts",
#         "followers": "9,100 followers",
#         "bio": "210 following"
#     },
#     {
#         "name": "koramangala_coder",
#         "posts": "120 posts",
#         "followers": "2,800 followers",
#         "bio": "95 following"
#     },
#     {
#         "name": "blrcowork_chronicles",
#         "posts": "480 posts",
#         "followers": "6,700 followers",
#         "bio": "180 following"
#     },
#     {
#         "name": "devhub_koramangala",
#         "posts": "210 posts",
#         "followers": "4,500 followers",
#         "bio": "60 following"
#     },
#     {
#         "name": "ai_bengaluru",
#         "posts": "150 posts",
#         "followers": "15.2K followers",
#         "bio": "140 following"
#     },
#     {
#         "name": "frontend_blr",
#         "posts": "95 posts",
#         "followers": "3,900 followers",
#         "bio": "30 following"
#     },
#     {
#         "name": "hsr_startup_stories",
#         "posts": "600 posts",
#         "followers": "22K followers",
#         "bio": "300 following"
#     },
#     {
#         "name": "python_wallah_blr",
#         "posts": "80 posts",
#         "followers": "1,700 followers",
#         "bio": "40 following"
#     },
#     {
#         "name": "btm_dev_cafe",
#         "posts": "140 posts",
#         "followers": "2,200 followers",
#         "bio": "120 following"
#     },
#     {
#         "name": "blrautomation_club",
#         "posts": "90 posts",
#         "followers": "5,800 followers",
#         "bio": "65 following"
#     },
#     {
#         "name": "coding_koramangala",
#         "posts": "70 posts",
#         "followers": "1,350 followers",
#         "bio": "15 following"
#     },
#     {
#         "name": "devlife_bangalore",
#         "posts": "430 posts",
#         "followers": "18K followers",
#         "bio": "450 following"
#     },
#     {
#         "name": "cloud_blr",
#         "posts": "160 posts",
#         "followers": "9,400 followers",
#         "bio": "210 following"
#     },
#     {
#         "name": "electroniccity_coder",
#         "posts": "100 posts",
#         "followers": "3,100 followers",
#         "bio": "55 following"
#     },
#     {
#         "name": "bangalore_datascience_club",
#         "posts": "240 posts",
#         "followers": "12.7K followers",
#         "bio": "110 following"
#     },
#     {
#         "name": "blrmobiledevs",
#         "posts": "130 posts",
#         "followers": "4,200 followers",
#         "bio": "80 following"
#     },
#     {
#         "name": "react_bangalore",
#         "posts": "300 posts",
#         "followers": "14K followers",
#         "bio": "200 following"
#     },
#     {
#         "name": "devs_of_whitefield",
#         "posts": "190 posts",
#         "followers": "6,600 followers",
#         "bio": "150 following"
#     },
#     {
#         "name": "indiranagar_debugger",
#         "posts": "75 posts",
#         "followers": "2,000 followers",
#         "bio": "30 following"
#     },
#     {
#         "name": "koramangala_ai_meet",
#         "posts": "85 posts",
#         "followers": "7,400 followers",
#         "bio": "22 following"
#     },
#     {
#         "name": "blrit_guy",
#         "posts": "230 posts",
#         "followers": "5,300 followers",
#         "bio": "200 following"
#     },
#     {
#         "name": "startup_grind_bangalore",
#         "posts": "1,100 posts",
#         "followers": "38K followers",
#         "bio": "420 following"
#     },
#     {
#         "name": "coding_in_indiranagar",
#         "posts": "60 posts",
#         "followers": "1,100 followers",
#         "bio": "25 following"
#     },
#     {
#         "name": "devwalk_blr",
#         "posts": "50 posts",
#         "followers": "900 followers",
#         "bio": "15 following"
#     },
#     {
#         "name": "bellandur_bug_hunter",
#         "posts": "110 posts",
#         "followers": "3,900 followers",
#         "bio": "75 following"
#     },
#     {
#         "name": "blrcoders_space",
#         "posts": "340 posts",
#         "followers": "25K followers",
#         "bio": "300 following"
#     },
#     {
#         "name": "nextjs_blr",
#         "posts": "45 posts",
#         "followers": "2,300 followers",
#         "bio": "40 following"
#     },
#     {
#         "name": "techpark_musings",
#         "posts": "130 posts",
#         "followers": "6,000 followers",
#         "bio": "100 following"
#     },
#     {
#         "name": "koramangala_freelancers",
#         "posts": "200 posts",
#         "followers": "4,000 followers",
#         "bio": "70 following"
#     },
#     {
#         "name": "blronlinejobs",
#         "posts": "560 posts",
#         "followers": "21K followers",
#         "bio": "190 following"
#     },
#     {
#         "name": "datascience_daily_blr",
#         "posts": "150 posts",
#         "followers": "8,800 followers",
#         "bio": "140 following"
#     },
#     {
#         "name": "python_koramangala",
#         "posts": "42 posts",
#         "followers": "850 followers",
#         "bio": "12 following"
#     },
#     {
#         "name": "coding_chai_bangalore",
#         "posts": "280 posts",
#         "followers": "10K followers",
#         "bio": "230 following"
#     },
#     {
#         "name": "blrgitcommunity",
#         "posts": "75 posts",
#         "followers": "3,200 followers",
#         "bio": "20 following"
#     },
#     {
#         "name": "indiranagar_startups",
#         "posts": "320 posts",
#         "followers": "12.5K followers",
#         "bio": "100 following"
#     },
#     {
#         "name": "machinelearning_blr",
#         "posts": "210 posts",
#         "followers": "19K followers",
#         "bio": "250 following"
#     },
#     {
#         "name": "koramangala_script_kiddie",
#         "posts": "55 posts",
#         "followers": "1,050 followers",
#         "bio": "18 following"
#     },
#     {
#         "name": "hsr_dev_buddy",
#         "posts": "120 posts",
#         "followers": "2,700 followers",
#         "bio": "40 following"
#     },
#     {
#         "name": "blrcloudhackers",
#         "posts": "140 posts",
#         "followers": "7,900 followers",
#         "bio": "200 following"
#     },
#     {
#         "name": "techwriter_blr",
#         "posts": "60 posts",
#         "followers": "1,900 followers",
#         "bio": "50 following"
#     },
#     {
#         "name": "dev_canteen_koramangala",
#         "posts": "180 posts",
#         "followers": "5,400 followers",
#         "bio": "120 following"
#     },
#     {
#         "name": "pythonlady_blr",
#         "posts": "70 posts",
#         "followers": "4,200 followers",
#         "bio": "35 following"
#     },
#     {
#         "name": "bangalore_oss",
#         "posts": "250 posts",
#         "followers": "9,800 followers",
#         "bio": "90 following"
#     },
#     {
#         "name": "blr_ai_founders",
#         "posts": "85 posts",
#         "followers": "6,600 followers",
#         "bio": "70 following"
#     },
#     {
#         "name": "coders_of_bangalore",
#         "posts": "300 posts",
#         "followers": "17K followers",
#         "bio": "280 following"
#     },
#     {
#         "name": "dailydev_bangalore",
#         "posts": "180 posts",
#         "followers": "12.2K followers",
#         "bio": "200 following"
#     },
#     {
#         "name": "bangalore_backend",
#         "posts": "90 posts",
#         "followers": "4,800 followers",
#         "bio": "60 following"
#     },
#     {
#         "name": "ecity_techies",
#         "posts": "140 posts",
#         "followers": "3,900 followers",
#         "bio": "55 following"
#     },
#     {
#         "name": "fullstack_blr_club",
#         "posts": "110 posts",
#         "followers": "7,200 followers",
#         "bio": "85 following"
#     },
#     {
#         "name": "coding_runners_blr",
#         "posts": "100 posts",
#         "followers": "2,500 followers",
#         "bio": "35 following"
#     },
#     {
#         "name": "bangalore_engineers_diary",
#         "posts": "270 posts",
#         "followers": "8,500 followers",
#         "bio": "120 following"
#     }
# ]
